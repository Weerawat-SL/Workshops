# %%
! pip install selenium
! pip install beautifulsoup4
! pip install pandas
! pip install chromedriver

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import sys
import requests

# %%
import json

url = "https://covid-19-data.p.rapidapi.com/report/totals"
querystring = {"format":"json"}

headers = {
    'x-rapidapi-key': "96232db9c1mshc6868777fe201a9p1426f1jsn32e9447a0d3e",
    'x-rapidapi-host': "covid-19-data.p.rapidapi.com"
    }
response = requests.get(url,headers=headers, params=querystring)
result_conversion_rate = response.json()
result_conversion_rate
# Out:
# [{'confirmed': 580,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 17,
#   'active': 563,
#   'date': '2020-01-22'},
#  {'confirmed': 845,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 25,
#   'active': 820,
#   'date': '2020-01-23'},
#  {'confirmed': 1317,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 41,
#   'active': 1276,
#   'date': '2020-01-24'},
#  {'confirmed': 2015,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 56,
#   'active': 1959,
#   'date': '2020-01-25'},
#  {'confirmed': 2800,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 80,
#   'active': 2720,
#   'date': '2020-01-26'},
#  {'confirmed': 4581,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 106,
#   'active': 4475,
#   'date': '2020-01-27'},
#  {'confirmed': 6058,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 132,
#   'active': 5926,
#   'date': '2020-01-28'},
#  {'confirmed': 7813,
#   'recovered': 0,
#   'critical': 0,
#   'deaths': 170,
#   'active': 7643,
# ...

# %%
conversion_rate = pd.DataFrame.from_dict(result_conversion_rate)
conversion_rate[:300]
# Out:
#      confirmed  recovered  critical  deaths   active        date
# 0          580          0         0      17      563  2020-01-22
# 1          845          0         0      25      820  2020-01-23
# 2         1317          0         0      41     1276  2020-01-24
# 3         2015          0         0      56     1959  2020-01-25
# 4         2800          0         0      80     2720  2020-01-26
# ..         ...        ...       ...     ...      ...         ...
# 196   18965762   12156537     65511  710284  6098941  2020-08-05
# 197   19249528   12350509     65218  716736  6182283  2020-08-06
# 198   19532537   12537862     65131  723184  6271491  2020-08-07
# 199   19796949   12715384     65144  728809  6352756  2020-08-08
# 200   20016541   12892475     64852  733607  6390459  2020-08-09
#
# [201 rows x 6 columns]

# %%
conversion_rate.to_csv('Covid.csv', index=False, encoding='utf-8')

# %%
import seaborn as sns  # หาข้อมูลเพิ่มเติมได้ใน seaborn
import matplotlib.pyplot as plt
import pandas as pd

# %%
# แปลง Spark Dataframe เป็น Pandas Dataframe
dt_pd_subset = conversion_rate[0:500]
# Histogram
sns.distplot(dt_pd_subset['confirmed']) 
plt.show()
# Out:
# C:\Users\Keramost-PC\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import json

url = "https://covid-19-data.p.rapidapi.com/report/country/name"

querystring = {"name":"Italy","format":"json"}

headers = {
    'x-rapidapi-key': "96232db9c1mshc6868777fe201a9p1426f1jsn32e9447a0d3e",
    'x-rapidapi-host': "covid-19-data.p.rapidapi.com"
    }
response = requests.get(url,headers=headers, params=querystring)
result_conversion_rate = response.json()
result_conversion_rate
# Out:
# {'type': 'https://tools.ietf.org/html/rfc2616#section-10',
#  'title': 'An error occurred',
#  'status': 400,
#  'detail': 'Bad Request'}

# %%
url = "https://covid-19-data.p.rapidapi.com/report/totals"

querystring = {"format":"json"}

headers = {
    'x-rapidapi-key': "96232db9c1mshc6868777fe201a9p1426f1jsn32e9447a0d3e",
    'x-rapidapi-host': "covid-19-data.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response.text
# Out:
# '{"message":"You have exceeded the rate limit per second for your plan, BASIC, by the API provider"}'
