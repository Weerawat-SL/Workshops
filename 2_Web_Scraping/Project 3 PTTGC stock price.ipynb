# %%
! pip install pandas_datareader

# %%
import pandas_datareader as pdr
import datetime
pttgc = pdr.get_data_yahoo('PTTGC.BK', 
                          start=datetime.datetime(2005, 10, 1), 
                          end=datetime.datetime.now())
pttgc
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2011-10-21  56.00  53.25  56.00  54.00  41140300.0  34.875500
# 2011-10-25  62.50  55.00  55.50  62.00  84388600.0  40.042233
# 2011-10-26  63.00  60.00  61.00  61.75  54874700.0  39.880783
# 2011-10-27  64.75  63.25  63.50  64.25  64698200.0  41.495373
# 2011-10-28  68.50  65.00  65.00  66.50  80811500.0  42.948528
# ...           ...    ...    ...    ...         ...        ...
# 2021-11-15  62.00  61.25  61.50  61.50   5988000.0  61.500000
# 2021-11-16  62.25  61.25  61.75  61.50   7875500.0  61.500000
# 2021-11-17  61.75  60.75  61.50  60.75  11968600.0  60.750000
# 2021-11-18  61.25  60.25  60.50  61.25   8192000.0  61.250000
# 2021-11-19  61.75  60.75  61.25  60.75  14445700.0  60.750000
#
# [2459 rows x 6 columns]

# %%
pttgc.to_csv('PTTGC_StockPrice.csv', encoding='utf-8')
